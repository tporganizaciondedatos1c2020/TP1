# %%
#Llamar al dataloader
# %run DataLoader.ipynb
import re
import matplotlib.gridspec as grd

# %%
text = "este es un texto con url https://stackoverflow.com/questions/839994/extracting-a-url-in-python  despues otro https://stackoverflow.com/questions/839994/extracting-a-url-in-python "
re.sub(r"http\S+", "", text)
# Out:
# 'este es un texto con url   despues otro  '

# %%
text
# Out:
# 'este es un texto con url https://stackoverflow.com/questions/839994/extracting-a-url-in-python  despues otro https://stackoverflow.com/questions/839994/extracting-a-url-in-python '

# %%
def containsURL(text):
    #regex from https://daringfireball.net/2010/07/improved_regex_for_matching_urls
    #URL_REGEX = r"""(?i)\b((?:https?:(?:/{1,3}|[a-z0-9%])|[a-z0-9.\-]+[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)/)(?:[^\s()<>{}\[\]]+|\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\))+(?:\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’])|(?:(?<!@)[a-z0-9]+(?:[.\-][a-z0-9]+)*[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)\b/?(?!@)))"""
    URL_REGEX = r"http\S+"
    m = re.search(URL_REGEX,text)
    if m is not None:
        return True
    return False

# %%
containsURL(text)
# Out:
# True

# %%
dataset['Tiene URL'] = dataset.text.apply(lambda x: containsURL(x))

# %%
dataset
# Out:
#       keyword location                                               text  \
# id
# 1         NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 4         NaN      NaN             Forest fire near La Ronge Sask. Canada
# 5         NaN      NaN  All residents asked to 'shelter in place' are ...
# 6         NaN      NaN  13,000 people receive #wildfires evacuation or...
# 7         NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
# ...       ...      ...                                                ...
# 10869     NaN      NaN  Two giant cranes holding a bridge collapse int...
# 10870     NaN      NaN  @aria_ahrary @TheTawniest The out of control w...
# 10871     NaN      NaN  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 10872     NaN      NaN  Police investigating after an e-bike collided ...
# 10873     NaN      NaN  The Latest: More Homes Razed by Northern Calif...
#
#        target  longitud  Tiene URL
# id
# ...

# %%
dataset.loc[dataset['Tiene URL'], :]
# Out:
#       keyword                       location  \
# id
# 48     ablaze                     Birmingham
# 49     ablaze  Est. September 2012 - Bristol
# 50     ablaze                         AFRICA
# 53     ablaze                     London, UK
# 55     ablaze                   World Wide!!
# ...       ...                            ...
# 10866     NaN                            NaN
# 10867     NaN                            NaN
# 10869     NaN                            NaN
# 10871     NaN                            NaN
# 10873     NaN                            NaN
#
#                                                     text  target  longitud  \
# id
# 48     @bbcmtd Wholesale Markets ablaze http://t.co/l...    True        55
# 49     We always try to bring the heavy. #metal #RT h...   False        67
# 50     #AFRICANBAZE: Breaking news:Nigeria flag set a...    True        82
# 53     On plus side LOOK AT THE SKY LAST NIGHT IT WAS...   False        76
# ...

# %%
urls_count = dataset['Tiene URL'].value_counts().reset_index()
urls_count.columns= ['Tipo', 'Cantidad']
urls_count['Tipo']=['tweets con URL', 'tweets sin URL']
urls_count
# Out:
#              Tipo  Cantidad
# 0  tweets con URL      3971
# 1  tweets sin URL      3642

# %%
with_url = urls_count.loc[urls_count['Tipo']=='tweets con URL','Cantidad']
without_url = urls_count.loc[urls_count['Tipo']=='tweets sin URL','Cantidad']

labels = 'Tweets con URL', 'Tweets sin URL'
sizes = [int(with_url), int(without_url)]
colors = ('coral','#1f77b4' )

fig1, ax1 = plt.subplots(figsize=(6,6))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',shadow=False, startangle=90, textprops={'fontsize': 15}, colors = colors)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
urls_count.loc[urls_count['Tipo']=='tweets sin URL','Cantidad']
# Out:
# 1    3642
# Name: Cantidad, dtype: int64

# %%
dataset['Texto sin url'] = dataset.text.apply(lambda x: re.sub(r"http\S+", "", x))
dataset
# Out:
#       keyword location                                               text  \
# id
# 1         NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 4         NaN      NaN             Forest fire near La Ronge Sask. Canada
# 5         NaN      NaN  All residents asked to 'shelter in place' are ...
# 6         NaN      NaN  13,000 people receive #wildfires evacuation or...
# 7         NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
# ...       ...      ...                                                ...
# 10869     NaN      NaN  Two giant cranes holding a bridge collapse int...
# 10870     NaN      NaN  @aria_ahrary @TheTawniest The out of control w...
# 10871     NaN      NaN  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 10872     NaN      NaN  Police investigating after an e-bike collided ...
# 10873     NaN      NaN  The Latest: More Homes Razed by Northern Calif...
#
#        target  longitud  Tiene URL  \
# id
# ...

# %%
dataset['longitud sin url'] = dataset.loc[:,'Texto sin url'].apply(lambda x : len(x))
dataset
# Out:
#       keyword location                                               text  \
# id
# 1         NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 4         NaN      NaN             Forest fire near La Ronge Sask. Canada
# 5         NaN      NaN  All residents asked to 'shelter in place' are ...
# 6         NaN      NaN  13,000 people receive #wildfires evacuation or...
# 7         NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
# ...       ...      ...                                                ...
# 10869     NaN      NaN  Two giant cranes holding a bridge collapse int...
# 10870     NaN      NaN  @aria_ahrary @TheTawniest The out of control w...
# 10871     NaN      NaN  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 10872     NaN      NaN  Police investigating after an e-bike collided ...
# 10873     NaN      NaN  The Latest: More Homes Razed by Northern Calif...
#
#        target  longitud  Tiene URL  \
# id
# ...

# %%
x_lim = dataset['longitud'].max()+20

fig, ax = plt.subplots(figsize=(10,6))

sns.distplot(dataset['longitud'], hist = False, kde = True,
                 kde_kws = {'shade': True, 'linewidth': 2}, label = 'Longitud de los tweets con URLs')
sns.distplot(dataset['longitud sin url'], hist = False, kde = True,
                 kde_kws = {'shade': True, 'linewidth': 2}, label = 'Longitud de los tweets sin URLs')

plt.xlabel('Longitud de los tweets',fontsize=20)
plt.ylabel('Densidad',fontsize=20)
plt.title('Densidad de los tweets según su longitud',fontsize=16,fontweight='bold', pad = 15)

plt.legend()

# %%
fig, ax = plt.subplots(figsize=(8,6))

data = dataset.loc[:,['longitud','longitud sin url']]
data.columns = ['Longitud de los tweets con URLs', 'Longitud de los tweets sin URLs']

sns.boxplot( data=data, palette="hls", ax=ax)



#plt.xlabel('Longitud de los tweets',fontsize=20)
plt.ylabel('Cantidad',fontsize=20)
plt.title('Longitud de tweets con y sin urls',fontsize=16,fontweight='bold', pad = 15)
# Out:
# Text(0.5, 1.0, 'Longitud de tweets con y sin urls')

# %%
x_lim = dataset['longitud'].max()+20

fig = plt.figure(figsize=(10,8))

gs = grd.GridSpec(2, 1, height_ratios=[6,4], hspace=0.6)


ax = plt.subplot(gs[0])


sns.distplot(dataset['longitud'], hist = False, kde = True, ax = ax, color = '#1f77b4',
                 kde_kws = {'shade': True, 'linewidth': 2}, label = 'Longitud de los tweets con URLs')
sns.distplot(dataset['longitud sin url'], hist = False, kde = True, ax = ax, color = 'coral',
                 kde_kws = {'shade': True, 'linewidth': 2}, label = 'Longitud de los tweets sin URLs')

plt.xlim(-1, x_lim)
plt.ylabel('Densidad',fontsize=16)
plt.title('Longitud de los tweets con y sin URLs',fontsize=16,fontweight='bold', pad = 15)
plt.xlabel('Longitud de los tweets',fontsize=16)
plt.legend()


ax1 = plt.subplot(gs[1])

data = dataset.loc[:,['longitud','longitud sin url']]
data.columns = ['Con URLs', 'Sin URLs']

colors = ('#1f77b4' , 'coral')
sns.boxplot( data=data, palette=colors, ax=ax1, orient='h')


plt.xlim(-1, x_lim)
plt.xlabel('Longitud de los tweets',fontsize=16)
# Out:
# Text(0.5, 0, 'Longitud de los tweets')
